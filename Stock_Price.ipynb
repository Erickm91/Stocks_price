# %% [markdown]
# ## Instalando Pandas_Datareader

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.22
#     Uninstalling yfinance-0.2.22:
#       Successfully uninstalled yfinance-0.2.22
# ...

# %% [markdown]
# ## Importando biblíotecas

# %%
import datetime as dt
import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
yf.pdr_override()

# %% [markdown]
# ### Criando algumas variavéis para facilitar o processo de busca do dataframe

# %%
inicio = dt.datetime(2010,1,1)
fim = dt.datetime.now()

# %% [markdown]
# ### Baixando o dataframe com algumas ações do bolsa de valores de São Paulo

# %%
lista_acoes = ['PETR4', 'VALE3', 'ITSA4', 'GGBR4','WEGE3']
acoes = [i + '.SA' for i in lista_acoes]
acoes
# Out:
# ['PETR4.SA', 'VALE3.SA', 'ITSA4.SA', 'GGBR4.SA', 'WEGE3.SA']

# %%
df = pdr.get_data_yahoo(acoes, inicio, fim)
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %% [markdown]
# ### Analisando as primeiras linhas do dataframe

# %%
df.head()
# Out:
#             Adj Close                                                Close  \
#              GGBR4.SA  ITSA4.SA   PETR4.SA   VALE3.SA  WEGE3.SA   GGBR4.SA
# Date
# 2010-01-04  17.489130  2.976796  11.541968  24.706104  2.067660  28.190475
# 2010-01-05  17.784554  2.967170  11.442998  24.936420  2.063148  28.666666
# 2010-01-06  17.902716  2.931073  11.597633  25.464228  2.074428  28.857141
# 2010-01-07  17.500937  2.914227  11.489390  25.569790  2.109396  28.209522
# 2010-01-08  17.453672  2.892569  11.427534  25.819300  2.186101  28.133333
#
#                                                       ...       Open  \
#             ITSA4.SA   PETR4.SA   VALE3.SA  WEGE3.SA  ...   GGBR4.SA
# Date                                                  ...
# 2010-01-04  5.897140  37.320000  51.490002  2.711538  ...  27.904760
# 2010-01-05  5.878071  37.000000  51.970001  2.705621  ...  28.323809
# 2010-01-06  5.806562  37.500000  53.070000  2.720414  ...  28.533333
# ...

# %% [markdown]
# ### Analisando as últimas linhas do dataframe

# %%
df.tail()
# Out:
#             Adj Close                                                 Close  \
#              GGBR4.SA  ITSA4.SA   PETR4.SA   VALE3.SA   WEGE3.SA   GGBR4.SA
# Date
# 2023-08-15  25.345280  9.465958  30.860001  61.290001  39.349998  25.780001
# 2023-08-16  25.325615  9.396428  31.540001  61.049999  37.610001  25.760000
# 2023-08-17  25.207638  9.316965  31.440001  61.910000  36.910000  25.639999
# 2023-08-18  25.070000  9.370000  31.520000  61.220001  36.259998  25.500000
# 2023-08-21  24.820000  9.250000  31.309999  61.299999  35.889999  24.820000
#
#                                                        ...       Open  \
#             ITSA4.SA   PETR4.SA   VALE3.SA   WEGE3.SA  ...   GGBR4.SA
# Date                                                   ...
# 2023-08-15  9.489863  30.860001  61.290001  39.349998  ...  26.000000
# 2023-08-16  9.420158  31.540001  61.049999  37.610001  ...  25.930000
# 2023-08-17  9.340495  31.440001  61.910000  36.910000  ...  26.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3385 entries, 2010-01-04 to 2023-08-21
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, GGBR4.SA)  3385 non-null   float64
#  1   (Adj Close, ITSA4.SA)  3385 non-null   float64
#  2   (Adj Close, PETR4.SA)  3385 non-null   float64
#  3   (Adj Close, VALE3.SA)  3385 non-null   float64
#  4   (Adj Close, WEGE3.SA)  3385 non-null   float64
#  5   (Close, GGBR4.SA)      3385 non-null   float64
#  6   (Close, ITSA4.SA)      3385 non-null   float64
#  7   (Close, PETR4.SA)      3385 non-null   float64
#  8   (Close, VALE3.SA)      3385 non-null   float64
#  9   (Close, WEGE3.SA)      3385 non-null   float64
#  10  (High, GGBR4.SA)       3385 non-null   float64
#  11  (High, ITSA4.SA)       3385 non-null   float64
#  12  (High, PETR4.SA)       3385 non-null   float64
#  13  (High, VALE3.SA)       3385 non-null   float64
# ...

# %%
## Observando se há números nulos no dataframe
df.isnull().sum()
# Out:
# Adj Close  GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# Close      GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# High       GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# Low        GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# Open       GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# Volume     GGBR4.SA    0
#            ITSA4.SA    0
#            PETR4.SA    0
#            VALE3.SA    0
#            WEGE3.SA    0
# dtype: int64

# %% [markdown]
# ### Pegando a coluna close para fazer algumas visualizações

# %%
close = df['Close']
close.head()
# Out:
#              GGBR4.SA  ITSA4.SA   PETR4.SA   VALE3.SA  WEGE3.SA
# Date
# 2010-01-04  28.190475  5.897140  37.320000  51.490002  2.711538
# 2010-01-05  28.666666  5.878071  37.000000  51.970001  2.705621
# 2010-01-06  28.857141  5.806562  37.500000  53.070000  2.720414
# 2010-01-07  28.209522  5.773191  37.150002  53.290001  2.766272
# 2010-01-08  28.133333  5.730285  36.950001  53.810001  2.866863

# %%
close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3385 entries, 2010-01-04 to 2023-08-21
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GGBR4.SA  3385 non-null   float64
#  1   ITSA4.SA  3385 non-null   float64
#  2   PETR4.SA  3385 non-null   float64
#  3   VALE3.SA  3385 non-null   float64
#  4   WEGE3.SA  3385 non-null   float64
# dtypes: float64(5)
# memory usage: 158.7 KB

# %%
type(close)
# Out:
# pandas.core.frame.DataFrame

# %%
close.describe( percentiles=[0.1,0.5,0.9])
# Out:
#           GGBR4.SA     ITSA4.SA     PETR4.SA     VALE3.SA     WEGE3.SA
# count  3385.000000  3385.000000  3385.000000  3385.000000  3385.000000
# mean     16.548586     7.350315    21.275571    47.832739    13.092370
# std       6.727844     2.039697     7.094334    23.115796    12.833785
# min       3.123809     3.968652     4.200000     8.600000     2.218934
# 10%       8.647619     5.028040    11.604000    19.338000     2.797632
# 50%      15.380952     6.859860    21.549999    44.689999     6.584615
# 90%      26.339047    10.290909    29.784000    84.229999    36.606000
# max      35.857143    12.424242    37.720001   118.720001    46.105000

# %% [markdown]
# ### Plotando a coluna CLOSE das ações

# %% [markdown]
# ### Importando a biblíoteca Plotly para uma visualização mais interativa

# %%
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)

pd.options.plotting.backend = 'plotly'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
close.plot()
# Out:
# <div>                            <div id="4cd7197a-2b6a-4a4d-9380-1bda41049f3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cd7197a-2b6a-4a4d-9380-1bda41049f3e")) {                    Plotly.newPlot(                        "4cd7197a-2b6a-4a4d-9380-1bda41049f3e",                        [{"hovertemplate":"variable=GGBR4.SA<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GGBR4.SA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GGBR4.SA","showlegend":true,"x":["2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-01-18T00:0
# ...

# %% [markdown]
# ## PETROBRAS

# %%
petro_close = close['PETR4.SA']
petro_close.head()
# Out:
# Date
# 2010-01-04    37.320000
# 2010-01-05    37.000000
# 2010-01-06    37.500000
# 2010-01-07    37.150002
# 2010-01-08    36.950001
# Name: PETR4.SA, dtype: float64

# %%
petro_close.tail()
# Out:
# Date
# 2023-08-15    30.860001
# 2023-08-16    31.540001
# 2023-08-17    31.440001
# 2023-08-18    31.520000
# 2023-08-21    31.309999
# Name: PETR4.SA, dtype: float64

# %%
type(petro_close)
# Out:
# pandas.core.series.Series

# %%
sns.boxplot(petro_close)
plt.title('Boxplot CLOSE Petrobrás');
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
petro_close.iloc[0]
# Out:
# 37.31999969482422

# %%
petro_close.iloc[-1]
# Out:
# 31.309999465942383

# %%
perct_chg_petro = (petro_close.iloc[-1] - petro_close.iloc[0]) / petro_close.iloc[0] * 100
perct_chg_petro
# Out:
# -16.10396644701833

# %% [markdown]
# ## VALE

# %%
vale_close = close['VALE3.SA']
vale_close.tail()
# Out:
# Date
# 2023-08-15    61.290001
# 2023-08-16    61.049999
# 2023-08-17    61.910000
# 2023-08-18    61.220001
# 2023-08-21    61.299999
# Name: VALE3.SA, dtype: float64

# %%
vale_close.iloc[0]
# Out:
# 51.4900016784668

# %%
vale_close.iloc[-1]
# Out:
# 61.29999923706055

# %%
perct_chg_vale = (vale_close.iloc[-1] - vale_close.iloc[0]) / vale_close.iloc[0] * 100
perct_chg_vale
# Out:
# 19.052237791431857

# %%
sns.boxplot(vale_close)
plt.title('Boxplot CLOSE Vale');
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## ITAÚ

# %%
itau_close = close['ITSA4.SA']
itau_close.tail()
# Out:
# Date
# 2023-08-15    9.489863
# 2023-08-16    9.420158
# 2023-08-17    9.340495
# 2023-08-18    9.370000
# 2023-08-21    9.250000
# Name: ITSA4.SA, dtype: float64

# %%
itau_close.iloc[0]
# Out:
# 5.897140026092529

# %%
itau_close.iloc[-1]
# Out:
# 9.25

# %%
perct_chg_itau = (itau_close.iloc[-1] - itau_close.iloc[0]) / itau_close.iloc[0] * 100
perct_chg_itau
# Out:
# 56.85569545699071

# %%
sns.boxplot(itau_close)
plt.title('Boxplot CLOSE Itaú');
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## GERDAU

# %%
gerdau_close = close['GGBR4.SA']
gerdau_close.tail()
# Out:
# Date
# 2023-08-15    25.780001
# 2023-08-16    25.760000
# 2023-08-17    25.639999
# 2023-08-18    25.500000
# 2023-08-21    24.820000
# Name: GGBR4.SA, dtype: float64

# %%
gerdau_close.iloc[0]
# Out:
# 28.190475463867188

# %%
gerdau_close.iloc[-1]
# Out:
# 24.81999969482422

# %%
perct_chg_gerdau = (gerdau_close.iloc[-1] - gerdau_close.iloc[0]) / gerdau_close.iloc[0] * 100
perct_chg_gerdau.round(2)
# Out:
# -11.96

# %%
sns.boxplot(gerdau_close)
plt.title('Boxplot CLOSE Gerdau');
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## WEG

# %%
weg_close = close['WEGE3.SA']
weg_close.tail()
# Out:
# Date
# 2023-08-15    39.349998
# 2023-08-16    37.610001
# 2023-08-17    36.910000
# 2023-08-18    36.259998
# 2023-08-21    35.889999
# Name: WEGE3.SA, dtype: float64

# %%
weg_close.iloc[0]
# Out:
# 2.711538076400757

# %%
weg_close.iloc[-1]
# Out:
# 35.88999938964844

# %%
perct_chg_weg = (weg_close.iloc[-1] - weg_close.iloc[0]) / weg_close.iloc[0] * 100
perct_chg_weg
# Out:
# 1223.603002370084

# %%
sns.boxplot(weg_close)
plt.title('Boxplot CLOSE Weg');
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
print('Petrobras ganho/perda percentual =', perct_chg_petro.round(2)),
print('Vale ganho/perda percentual =', perct_chg_vale.round(2)),
print('Itaú ganho/perda percentual =', perct_chg_itau.round(2)),
print('Gerdau ganho/perda percentual =', perct_chg_gerdau.round(2)),
print('Weg ganho/perda percentual =', perct_chg_weg.round(2))
# Out:
# Petrobras ganho/perda percentual = -16.1
# Vale ganho/perda percentual = 19.05
# Itaú ganho/perda percentual = 56.86
# Gerdau ganho/perda percentual = -11.96
# Weg ganho/perda percentual = 1223.6

# %% [markdown]
# #### Podemos observar que a Petrobras teve uma maior perda percentual no período e que a Weg teve o maior ganho percentual no mesmo período.

# %%
plt.figure( figsize=(8,8) )
sns.heatmap(close.corr(), annot=True);

# %% [markdown]
# # Predição com Decision Tree Regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
X = df.drop(columns = ['Close'])
y = df['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
model = DecisionTreeRegressor(max_depth = 3)
model.fit(X_train, y_train)
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
# DecisionTreeRegressor(max_depth=3)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# C:\Users\Erick\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
# array([[ 7.07914182,  5.96229005, 10.03499999, 17.61172515,  6.08333846],
#        [12.69609516,  6.35076926, 16.60846745, 31.42143678,  5.68656974],
#        [15.25372019,  6.58623299, 20.95164342, 41.5489972 ,  5.68199731],
#        ...,
#        [12.69609516,  6.35076926, 16.60846745, 31.42143678,  5.68656974],
#        [ 7.07914182,  5.96229005, 10.03499999, 17.61172515,  6.08333846],
#        [17.68058681,  8.16951629, 26.22091354, 51.88964115,  8.17972761]])

# %% [markdown]
# # Medidas de Erro

# %%
from sklearn.metrics import mean_absolute_error
print(f'mean_absolute_error = ', mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f'mean_squared_error = ', mean_squared_error(y_test, y_pred))

from sklearn.metrics import mean_absolute_percentage_error
print(f'mean_absolute_percentage_error = ', mean_absolute_percentage_error(y_test, y_pred))

from sklearn.metrics import r2_score
print(f'r2_score = ', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error =  2.4556800287266656
# mean_squared_error =  10.975804541941296
# mean_absolute_percentage_error =  0.20890539438323982
# r2_score =  0.7573789032752634
